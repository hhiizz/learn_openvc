# %%
import cv2
from google.colab.patches import cv2_imshow
image1 = cv2.imread("./sample_data/123.jpg",4
)
cv2_imshow(image1)

cv2.imwrite('./zzzz.jpg',image1)
cv2.imwrite('./kkkk.jpg',image1,[cv2.IMWRITE_JPEG_QUALITY,50])
cv2.imwrite('./kkkk23.jpg',image1,[cv2.IMWRITE_JPEG_QUALITY,5])
image2 = cv2.imread("./zzzz.jpg")
image3 = cv2.imread("./kkkk.jpg")
image4 = cv2.imread("./kkkk23.jpg")
cv2_imshow(image2)
cv2_imshow(image3)
cv2_imshow(image4)
# Out:
# <PIL.Image.Image image mode=RGB size=200x187>
# <PIL.Image.Image image mode=RGB size=200x187>
# <PIL.Image.Image image mode=RGB size=200x187>
# <PIL.Image.Image image mode=RGB size=200x187>

# %% [markdown]
# # 新增區段
